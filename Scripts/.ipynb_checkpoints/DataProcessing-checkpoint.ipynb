# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
csv2013_06 = pd.read_csv("../RawData/CSVs/201306-citibike-tripdata.csv", low_memory=False)
df2013_06 = pd.DataFrame(csv2013_06)
df2013_06
# Out:
#         tripduration            starttime             stoptime  \
# 0                695  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1                693  2013-06-01 00:00:08  2013-06-01 00:11:41
# 2               2059  2013-06-01 00:00:44  2013-06-01 00:35:03
# 3                123  2013-06-01 00:01:04  2013-06-01 00:03:07
# 4               1521  2013-06-01 00:01:22  2013-06-01 00:26:43
# ...              ...                  ...                  ...
# 577698           925  2013-06-30 23:59:27  2013-07-01 00:14:52
# 577699           279  2013-06-30 23:59:36  2013-07-01 00:04:15
# 577700           161  2013-06-30 23:59:33  2013-07-01 00:02:14
# 577701           909  2013-06-30 23:59:47  2013-07-01 00:14:56
# 577702           634  2013-07-01 00:00:00  2013-07-01 00:10:34
#
#         start station id      start station name  start station latitude  \
# 0                    444      Broadway & W 24 St               40.742354
# ...

# %%
csv2021_06 = pd.read_csv("../RawData/CSVs/202106-citibike-tripdata.csv", low_memory=False)
df2021_06 = pd.DataFrame(csv2021_06)
csvJC2021_06 = pd.read_csv("../RawData/CSVs/JC-202106-citibike-tripdata.csv", low_memory=False)
dfJC2021_06 = pd.DataFrame(csvJC2021_06)
df2021_06 = df2021_06.append(dfJC2021_06)
df2021_06
# Out:
#                 ride_id rideable_type           started_at  \
# 0      6339C86D47EC0FAB   docked_bike  2021-06-02 17:18:45
# 1      CDE3C147775B4002   docked_bike  2021-06-04 21:01:46
# 2      D335C3F6B412B846   docked_bike  2021-06-15 16:39:36
# 3      8DA6810777C89735   docked_bike  2021-06-08 11:36:40
# 4      62D9B66A3A1D9FDF   docked_bike  2021-06-18 12:48:43
# ...                 ...           ...                  ...
# 71423  8DA32148B9DC1B15  classic_bike  2021-06-23 18:27:20
# 71424  E209A4E2ACA17FA2   docked_bike  2021-06-15 19:05:53
# 71425  A26E32E2F99755D8  classic_bike  2021-06-22 17:44:23
# 71426  D86BB03B2C61CB61   docked_bike  2021-06-07 14:48:34
# 71427  7BACA2F29D40FE7B  classic_bike  2021-06-30 07:47:49
#
#                   ended_at     start_station_name start_station_id  \
# 0      2021-06-02 17:26:17        W 51 St & 6 Ave           6740.1
# 1      2021-06-04 21:32:09       W 56 St & 10 Ave          6955.01
# ...

# %%
csv2021_01 = pd.read_csv("../RawData/CSVs/202101-citibike-tripdata.csv", low_memory=False)
df2021_01 = pd.DataFrame(csv2021_01)
df2021_01
csvJC2021_01 = pd.read_csv("../RawData/CSVs/JC-202101-citibike-tripdata.csv", low_memory=False)
dfJC2021_01 = pd.DataFrame(csvJC2021_01)
df2021_01 = df2021_01.append(dfJC2021_01)
df2021_01
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1              2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2              1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3              2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4               959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id          start station name  start station latitude  \
# ...

# %%
print("2013_06")
print(df2013_06.value_counts("usertype"))
print(df2013_06.value_counts("usertype", normalize=True))
print("------------------------------------")
print("2021_06")
print(df2021_06.value_counts("member_casual"))
print(df2021_06.value_counts("member_casual", normalize=True))
# Out:
# 2013_06
# usertype
# Subscriber    337384
# Customer      240319
# dtype: int64
# usertype
# Subscriber    0.584009
# Customer      0.415991
# dtype: float64
# ------------------------------------
# 2021_06
# member_casual
# member    2181798
# casual    1067147
# dtype: int64
# member_casual
# member    0.67154
# casual    0.32846
# dtype: float64

# %%
print("2013-06")
print(df2013_06.value_counts("gender"))
print(df2013_06.value_counts("gender", normalize=True))
print("-------------------------")
print("2021_01")
print(df2021_01.value_counts("gender"))
print(df2021_01.value_counts("gender", normalize=True))
# Out:
# 2013-06
# gender
# 1    263492
# 0    240748
# 2     73463
# dtype: int64
# gender
# 1    0.456103
# 0    0.416733
# 2    0.127164
# dtype: float64
# -------------------------
# 2021_01
# gender
# 1    722418
# 2    292460
# 0     92092
# dtype: int64
# gender
# 1    0.652608
# 2    0.264199
# 0    0.083193
# dtype: float64
