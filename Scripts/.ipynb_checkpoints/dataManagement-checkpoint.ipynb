# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
csv2013_06 = pd.read_csv("../RawData/CSVs/201306-citibike-tripdata.csv", low_memory=False)
df2013_06 = pd.DataFrame(csv2013_06)
csv2013_07 = pd.read_csv("../RawData/CSVs/2013-07 - Citi Bike trip data.csv", low_memory=False)
df2013_07 = pd.DataFrame(csv2013_07)
csv2013_08 = pd.read_csv("../RawData/CSVs/2013-08 - Citi Bike trip data.csv", low_memory=False)
df2013_08 = pd.DataFrame(csv2013_08)
csv2013_09 = pd.read_csv("../RawData/CSVs/2013-09 - Citi Bike trip data.csv", low_memory=False)
df2013_09 = pd.DataFrame(csv2013_09)
csv2013_10 = pd.read_csv("../RawData/CSVs/2013-10 - Citi Bike trip data.csv", low_memory=False)
df2013_10 = pd.DataFrame(csv2013_10)
csv2013_11 = pd.read_csv("../RawData/CSVs/2013-11 - Citi Bike trip data.csv", low_memory=False)
df2013_11 = pd.DataFrame(csv2013_11)
csv2013_12 = pd.read_csv("../RawData/CSVs/2013-12 - Citi Bike trip data.csv", low_memory=False)
df2013_12 = pd.DataFrame(csv2013_12)
all2013df = pd.concat([df2013_12, df2013_11, df2013_10, df2013_09, df2013_08, df2013_07, df2013_06])
all2013df = all2013df.dropna()
all2013df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1015  2013-12-01 00:00:03  2013-12-01 00:16:58               401
# 1           962  2013-12-01 00:00:07  2013-12-01 00:16:09               312
# 2           768  2013-12-01 00:00:15  2013-12-01 00:13:03               326
# 3           218  2013-12-01 00:00:49  2013-12-01 00:04:27              2021
# 4           550  2013-12-01 00:01:28  2013-12-01 00:10:38               439
#
#         start station name  start station latitude  start station longitude  \
# 0  Allen St & Rivington St               40.720196               -73.989978
# 1  Allen St & E Houston St               40.722055               -73.989111
# 2          E 11 St & 1 Ave               40.729538               -73.984267
# 3          W 45 St & 8 Ave               40.759291               -73.988597
# 4           E 4 St & 2 Ave               40.726281               -73.989780
#
# ...

# %%
csv2014_01 = pd.read_csv("../RawData/CSVs/2014-01 - Citi Bike trip data.csv", low_memory=False)
df2014_01 = pd.DataFrame(csv2014_01)
csv2014_02 = pd.read_csv("../RawData/CSVs/2014-02 - Citi Bike trip data.csv", low_memory=False)
df2014_02 = pd.DataFrame(csv2014_02)
csv2014_03 = pd.read_csv("../RawData/CSVs/2014-03 - Citi Bike trip data.csv", low_memory=False)
df2014_03 = pd.DataFrame(csv2014_03)
csv2014_04 = pd.read_csv("../RawData/CSVs/2014-04 - Citi Bike trip data.csv", low_memory=False)
df2014_04 = pd.DataFrame(csv2014_04)
csv2014_05 = pd.read_csv("../RawData/CSVs/2014-05 - Citi Bike trip data.csv", low_memory=False)
df2014_05 = pd.DataFrame(csv2014_05)
csv2014_06 = pd.read_csv("../RawData/CSVs/2014-06 - Citi Bike trip data.csv", low_memory=False)
df2014_06 = pd.DataFrame(csv2014_06)
csv2014_07 = pd.read_csv("../RawData/CSVs/2014-07 - Citi Bike trip data.csv", low_memory=False)
df2014_07 = pd.DataFrame(csv2014_07)
csv2014_08 = pd.read_csv("../RawData/CSVs/2014-08 - Citi Bike trip data.csv", low_memory=False)
df2014_08 = pd.DataFrame(csv2014_08)
csv2014_09 = pd.read_csv("../RawData/CSVs/201409-citibike-tripdata.csv", low_memory=False)
df2014_09 = pd.DataFrame(csv2014_09)
csv2014_10 = pd.read_csv("../RawData/CSVs/201410-citibike-tripdata.csv", low_memory=False)
df2014_10 = pd.DataFrame(csv2014_10)
csv2014_11 = pd.read_csv("../RawData/CSVs/201411-citibike-tripdata.csv", low_memory=False)
df2014_11 = pd.DataFrame(csv2014_11)
csv2014_12 = pd.read_csv("../RawData/CSVs/201412-citibike-tripdata.csv", low_memory=False)
df2014_12 = pd.DataFrame(csv2014_12)
all2014df = pd.concat([df2014_12, df2014_11, df2014_10, df2014_09, df2014_08, df2014_07, df2014_06, df2014_05, df2014_04, df2014_03, df2014_02, df2014_01])
all2014df = all2014df.dropna()
all2014df.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 1           275  12/1/2014 00:00:43  12/1/2014 00:05:18               498
# 2           450  12/1/2014 00:01:22  12/1/2014 00:08:52               444
# 4           331  12/1/2014 00:02:21  12/1/2014 00:07:52               519
# 5           162  12/1/2014 00:02:37  12/1/2014 00:05:19               229
# 6           155  12/1/2014 00:02:43  12/1/2014 00:05:18               229
#
#       start station name  start station latitude  start station longitude  \
# 1     Broadway & W 32 St               40.748549               -73.988084
# 2     Broadway & W 24 St               40.742354               -73.989151
# 4  Pershing Square North               40.751873               -73.977706
# 5         Great Jones St               40.727434               -73.993790
# 6         Great Jones St               40.727434               -73.993790
#
#    end station id             end station name  end station latitude  \
# ...

# %%
csv2015_01 = pd.read_csv("../RawData/CSVs/201501-citibike-tripdata.csv", low_memory=False)
df2015_01 = pd.DataFrame(csv2015_01)
csv2015_02 = pd.read_csv("../RawData/CSVs/201502-citibike-tripdata.csv", low_memory=False)
df2015_02 = pd.DataFrame(csv2015_02)
csv2015_03 = pd.read_csv("../RawData/CSVs/201503-citibike-tripdata.csv", low_memory=False)
df2015_03 = pd.DataFrame(csv2015_03)
csv2015_04 = pd.read_csv("../RawData/CSVs/201504-citibike-tripdata.csv", low_memory=False)
df2015_04 = pd.DataFrame(csv2015_04)
csv2015_05 = pd.read_csv("../RawData/CSVs/201505-citibike-tripdata.csv", low_memory=False)
df2015_05 = pd.DataFrame(csv2015_05)
csv2015_06 = pd.read_csv("../RawData/CSVs/201506-citibike-tripdata.csv", low_memory=False)
df2015_06 = pd.DataFrame(csv2015_06)
csv2015_07 = pd.read_csv("../RawData/CSVs/201507-citibike-tripdata.csv", low_memory=False)
df2015_07 = pd.DataFrame(csv2015_07)
csv2015_08 = pd.read_csv("../RawData/CSVs/201508-citibike-tripdata.csv", low_memory=False)
df2015_08 = pd.DataFrame(csv2015_08)
csv2015_09 = pd.read_csv("../RawData/CSVs/201509-citibike-tripdata.csv", low_memory=False)
df2015_09 = pd.DataFrame(csv2015_09)
csv2015_10 = pd.read_csv("../RawData/CSVs/201510-citibike-tripdata.csv", low_memory=False)
df2015_10 = pd.DataFrame(csv2015_10)
csv2015_11 = pd.read_csv("../RawData/CSVs/201511-citibike-tripdata.csv", low_memory=False)
df2015_11 = pd.DataFrame(csv2015_11)
csv2015_12 = pd.read_csv("../RawData/CSVs/201512-citibike-tripdata.csv", low_memory=False)
df2015_12 = pd.DataFrame(csv2015_12)
df2015 = pd.concat([df2015_12, df2015_11, df2015_10, df2015_09, df2015_08, df2015_07, df2015_06, df2015_05, df2015_04, df2015_03, df2015_02, df2015_01])
df2015 = df2015.dropna()
df2015.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           475  12/1/2015 07:35:36  12/1/2015 07:43:32                72
# 1           684  12/1/2015 07:38:15  12/1/2015 07:49:39                72
# 2          1063  12/1/2015 07:44:49  12/1/2015 08:02:33                72
# 3          1075  12/1/2015 08:02:29  12/1/2015 08:20:24                72
# 4           293  12/1/2015 08:06:37  12/1/2015 08:11:30                72
#
#   start station name  start station latitude  start station longitude  \
# 0   W 52 St & 11 Ave               40.767272               -73.993929
# 1   W 52 St & 11 Ave               40.767272               -73.993929
# 2   W 52 St & 11 Ave               40.767272               -73.993929
# 3   W 52 St & 11 Ave               40.767272               -73.993929
# 4   W 52 St & 11 Ave               40.767272               -73.993929
#
#    end station id               end station name  end station latitude  \
# ...

# %%
csv2016_01 = pd.read_csv("../RawData/CSVs/201601-citibike-tripdata.csv", low_memory=False)
df2016_01 = pd.DataFrame(csv2016_01)
csv2016_02 = pd.read_csv("../RawData/CSVs/201602-citibike-tripdata.csv", low_memory=False)
df2016_02 = pd.DataFrame(csv2016_02)
csv2016_03 = pd.read_csv("../RawData/CSVs/201603-citibike-tripdata.csv", low_memory=False)
df2016_03 = pd.DataFrame(csv2016_03)
csv2016_04 = pd.read_csv("../RawData/CSVs/201604-citibike-tripdata.csv", low_memory=False)
df2016_04 = pd.DataFrame(csv2016_04)
csv2016_05 = pd.read_csv("../RawData/CSVs/201605-citibike-tripdata.csv", low_memory=False)
df2016_05 = pd.DataFrame(csv2016_05)
csv2016_06 = pd.read_csv("../RawData/CSVs/201606-citibike-tripdata.csv", low_memory=False)
df2016_06 = pd.DataFrame(csv2016_06)
csv2016_07 = pd.read_csv("../RawData/CSVs/201607-citibike-tripdata.csv", low_memory=False)
df2016_07 = pd.DataFrame(csv2016_07)
csv2016_08 = pd.read_csv("../RawData/CSVs/201608-citibike-tripdata.csv", low_memory=False)
df2016_08 = pd.DataFrame(csv2016_08)
csv2016_09 = pd.read_csv("../RawData/CSVs/201609-citibike-tripdata.csv", low_memory=False)
df2016_09 = pd.DataFrame(csv2016_09)
csv2016_10 = pd.read_csv("../RawData/CSVs/201610-citibike-tripdata.csv", low_memory=False)
df2016_10 = pd.DataFrame(csv2016_10)
df2016_10 = df2016_10.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csv2016_11 = pd.read_csv("../RawData/CSVs/201611-citibike-tripdata.csv", low_memory=False)
df2016_11 = pd.DataFrame(csv2016_11)
df2016_11 = df2016_11.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csv2016_12 = pd.read_csv("../RawData/CSVs/201612-citibike-tripdata.csv", low_memory=False)
df2016_12 = pd.DataFrame(csv2016_12)
df2016_12 = df2016_12.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
df2016 = pd.concat([df2016_12, df2016_11, df2016_10, df2016_09, df2016_08, df2016_07, df2016_06, df2016_05, df2016_04, df2016_03, df2016_03, df2016_01])
df2016 = df2016.dropna()
df2016.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           528  2016-12-01 00:00:04  2016-12-01 00:08:52               499
# 1           218  2016-12-01 00:00:28  2016-12-01 00:04:06              3418
# 2           399  2016-12-01 00:00:39  2016-12-01 00:07:19               297
# 3           254  2016-12-01 00:00:44  2016-12-01 00:04:59               405
# 4          1805  2016-12-01 00:00:54  2016-12-01 00:31:00               279
#
#               start station name  start station latitude  \
# 0             Broadway & W 60 St               40.769155
# 1   Plaza St West & Flatbush Ave               40.675021
# 2                E 15 St & 3 Ave               40.734232
# 3  Washington St & Gansevoort St               40.739323
# 4           Peck Slip & Front St               40.707873
#
#    start station longitude  end station id               end station name  \
# 0               -73.981918             228                E 48 St & 3 Ave
# ...

# %%
csv2017_01 = pd.read_csv("../RawData/CSVs/201701-citibike-tripdata.csv", low_memory=False)
df2017_01 = pd.DataFrame(csv2017_01)
df2017_01 = df2017_01.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csv2017_02 = pd.read_csv("../RawData/CSVs/201702-citibike-tripdata.csv", low_memory=False)
df2017_02 = pd.DataFrame(csv2017_02)
df2017_02 = df2017_02.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csv2017_03 = pd.read_csv("../RawData/CSVs/201703-citibike-tripdata.csv", low_memory=False)
df2017_03 = pd.DataFrame(csv2017_03)
df2017_03 = df2017_03.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csv2017_04 = pd.read_csv("../RawData/CSVs/201704-citibike-tripdata.csv", low_memory=False)
df2017_04 = pd.DataFrame(csv2017_04)
csv2017_05 = pd.read_csv("../RawData/CSVs/201705-citibike-tripdata.csv", low_memory=False)
df2017_05 = pd.DataFrame(csv2017_05)
csv2017_06 = pd.read_csv("../RawData/CSVs/201706-citibike-tripdata.csv", low_memory=False)
df2017_06 = pd.DataFrame(csv2017_06)
csv2017_07 = pd.read_csv("../RawData/CSVs/201707-citibike-tripdata.csv", low_memory=False)
df2017_07 = pd.DataFrame(csv2017_07)
csv2017_08 = pd.read_csv("../RawData/CSVs/201708-citibike-tripdata.csv", low_memory=False)
df2017_08 = pd.DataFrame(csv2017_08)
csv2017_09 = pd.read_csv("../RawData/CSVs/201709-citibike-tripdata.csv", low_memory=False)
df2017_09 = pd.DataFrame(csv2017_09)
csv2017_10 = pd.read_csv("../RawData/CSVs/201710-citibike-tripdata.csv", low_memory=False)
df2017_10 = pd.DataFrame(csv2017_10)
csv2017_11 = pd.read_csv("../RawData/CSVs/201711-citibike-tripdata.csv", low_memory=False)
df2017_11 = pd.DataFrame(csv2017_11)
csv2017_12 = pd.read_csv("../RawData/CSVs/201712-citibike-tripdata.csv", low_memory=False)
df2017_12 = pd.DataFrame(csv2017_12)
df2017 = pd.concat([df2017_12, df2017_11, df2017_10, df2017_09, df2017_08, df2017_07, df2017_06, df2017_05, df2017_04, df2017_03, df2017_02, df2017_01])
df2017 = df2017.dropna()
df2017.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           256  2017-12-01 00:00:00  2017-12-01 00:04:17               324
# 1           325  2017-12-01 00:00:17  2017-12-01 00:05:43               470
# 2           967  2017-12-01 00:00:19  2017-12-01 00:16:26               347
# 3           125  2017-12-01 00:00:20  2017-12-01 00:02:26              3077
# 4           451  2017-12-01 00:00:28  2017-12-01 00:08:00               368
#
#             start station name  start station latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1              W 20 St & 8 Ave               40.743453
# 2  Greenwich St & W Houston St               40.728846
# 3         Stagg St & Union Ave               40.708771
# 4           Carmine St & 6 Ave               40.730386
#
#    start station longitude  end station id        end station name  \
# 0               -73.981013             262         Washington Park
# ...

# %%
csv2018_01 = pd.read_csv("../RawData/CSVs/201801-citibike-tripdata.csv", low_memory=False)
df2018_01 = pd.DataFrame(csv2018_01)
csv2018_02 = pd.read_csv("../RawData/CSVs/201802-citibike-tripdata.csv", low_memory=False)
df2018_02 = pd.DataFrame(csv2018_02)
csv2018_03 = pd.read_csv("../RawData/CSVs/201803-citibike-tripdata.csv", low_memory=False)
df2018_03 = pd.DataFrame(csv2018_03)
csv2018_04 = pd.read_csv("../RawData/CSVs/201804-citibike-tripdata.csv", low_memory=False)
df2018_04 = pd.DataFrame(csv2018_04)
csv2018_05 = pd.read_csv("../RawData/CSVs/201805-citibike-tripdata.csv", low_memory=False)
df2018_05 = pd.DataFrame(csv2018_05)
csv2018_06 = pd.read_csv("../RawData/CSVs/201806-citibike-tripdata.csv", low_memory=False)
df2018_06 = pd.DataFrame(csv2018_06)
csv2018_07 = pd.read_csv("../RawData/CSVs/201807-citibike-tripdata.csv", low_memory=False)
df2018_07 = pd.DataFrame(csv2018_07)
csv2018_08 = pd.read_csv("../RawData/CSVs/201808-citibike-tripdata.csv", low_memory=False)
df2018_08 = pd.DataFrame(csv2018_08)
csv2018_09 = pd.read_csv("../RawData/CSVs/201809-citibike-tripdata.csv", low_memory=False)
df2018_09 = pd.DataFrame(csv2018_09)
csv2018_10 = pd.read_csv("../RawData/CSVs/201810-citibike-tripdata.csv", low_memory=False)
df2018_10 = pd.DataFrame(csv2018_10)
csv2018_11 = pd.read_csv("../RawData/CSVs/201811-citibike-tripdata.csv", low_memory=False)
df2018_11 = pd.DataFrame(csv2018_11)
csv2018_12 = pd.read_csv("../RawData/CSVs/201812-citibike-tripdata.csv", low_memory=False)
df2018_12 = pd.DataFrame(csv2018_12)
df2018 = pd.concat([df2018_12, df2018_11, df2018_10, df2018_09, df2018_08, df2018_07, df2018_06, df2018_05, df2018_04, df2018_03, df2018_02, df2018_01])
df2018 = df2018.dropna()
df2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           689  2018-12-01 00:00:04.3020  2018-12-01 00:11:33.8460
# 1           204  2018-12-01 00:00:05.5330  2018-12-01 00:03:30.5230
# 2           316  2018-12-01 00:00:10.2330  2018-12-01 00:05:27.2030
# 3           726  2018-12-01 00:00:21.9570  2018-12-01 00:12:28.1830
# 4           397  2018-12-01 00:00:29.6320  2018-12-01 00:07:07.4460
#
#    start station id          start station name  start station latitude  \
# 0            3359.0       E 68 St & Madison Ave               40.769157
# 1            3504.0    E 123 St & Lexington Ave               40.802926
# 2             270.0     Adelphi St & Myrtle Ave               40.693083
# 3             495.0            W 47 St & 10 Ave               40.762699
# 4             473.0  Rivington St & Chrystie St               40.721101
#
#    start station longitude  end station id            end station name  \
# ...

# %%
csv2019_01 = pd.read_csv("../RawData/CSVs/201901-citibike-tripdata.csv", low_memory=False)
df2019_01 = pd.DataFrame(csv2019_01)
csv2019_02 = pd.read_csv("../RawData/CSVs/201902-citibike-tripdata.csv", low_memory=False)
df2019_02 = pd.DataFrame(csv2019_02)
csv2019_03 = pd.read_csv("../RawData/CSVs/201903-citibike-tripdata.csv", low_memory=False)
df2019_03 = pd.DataFrame(csv2019_03)
csv2019_04 = pd.read_csv("../RawData/CSVs/201904-citibike-tripdata.csv", low_memory=False)
df2019_04 = pd.DataFrame(csv2019_04)
csv2019_05 = pd.read_csv("../RawData/CSVs/201905-citibike-tripdata.csv", low_memory=False)
df2019_05 = pd.DataFrame(csv2019_05)
csv2019_06 = pd.read_csv("../RawData/CSVs/201906-citibike-tripdata.csv", low_memory=False)
df2019_06 = pd.DataFrame(csv2019_06)
csv2019_07 = pd.read_csv("../RawData/CSVs/201907-citibike-tripdata.csv", low_memory=False)
df2019_07 = pd.DataFrame(csv2019_07)
csv2019_08 = pd.read_csv("../RawData/CSVs/201908-citibike-tripdata.csv", low_memory=False)
df2019_08 = pd.DataFrame(csv2019_08)
csv2019_09 = pd.read_csv("../RawData/CSVs/201909-citibike-tripdata.csv", low_memory=False)
df2019_09 = pd.DataFrame(csv2019_09)
csv2019_10 = pd.read_csv("../RawData/CSVs/201910-citibike-tripdata.csv", low_memory=False)
df2019_10 = pd.DataFrame(csv2019_10)
csv2019_11 = pd.read_csv("../RawData/CSVs/201911-citibike-tripdata.csv", low_memory=False)
df2019_11 = pd.DataFrame(csv2019_11)
csv2019_12 = pd.read_csv("../RawData/CSVs/201912-citibike-tripdata.csv", low_memory=False)
df2019_12 = pd.DataFrame(csv2019_12)
df2019 = pd.concat([df2019_12, df2019_11, df2019_10, df2019_09, df2019_08, df2019_07, df2019_06, df2019_05, df2019_04, df2019_03, df2019_02, df2019_01])
df2019 = df2019.dropna()
df2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1          1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2           723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3           404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4          1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
#
#    start station id      start station name  start station latitude  \
# 0            3382.0   Carroll St & Smith St               40.680611
# 1             362.0      Broadway & W 37 St               40.751726
# 2             146.0    Hudson St & Reade St               40.716250
# 3            3834.0  Irving Ave & Halsey St               40.694670
# 4             500.0      Broadway & W 51 St               40.762288
#
#    start station longitude  end station id              end station name  \
# ...

# %%
csv2020_01 = pd.read_csv("../RawData/CSVs/202001-citibike-tripdata.csv", low_memory=False)
df2020_01 = pd.DataFrame(csv2020_01)
csv2020_02 = pd.read_csv("../RawData/CSVs/202002-citibike-tripdata.csv", low_memory=False)
df2020_02 = pd.DataFrame(csv2020_02)
csv2020_03 = pd.read_csv("../RawData/CSVs/202003-citibike-tripdata.csv", low_memory=False)
df2020_03 = pd.DataFrame(csv2020_03)
csv2020_04 = pd.read_csv("../RawData/CSVs/202004-citibike-tripdata.csv", low_memory=False)
df2020_04 = pd.DataFrame(csv2020_04)
csv2020_05 = pd.read_csv("../RawData/CSVs/202005-citibike-tripdata.csv", low_memory=False)
df2020_05 = pd.DataFrame(csv2020_05)
csv2020_06 = pd.read_csv("../RawData/CSVs/202006-citibike-tripdata.csv", low_memory=False)
df2020_06 = pd.DataFrame(csv2020_06)
csv2020_07 = pd.read_csv("../RawData/CSVs/202007-citibike-tripdata.csv", low_memory=False)
df2020_07 = pd.DataFrame(csv2020_07)
csv2020_08 = pd.read_csv("../RawData/CSVs/202008-citibike-tripdata.csv", low_memory=False)
df2020_08 = pd.DataFrame(csv2020_08)
csv2020_09 = pd.read_csv("../RawData/CSVs/202009-citibike-tripdata.csv", low_memory=False)
df2020_09 = pd.DataFrame(csv2020_09)
csv2020_10 = pd.read_csv("../RawData/CSVs/202010-citibike-tripdata.csv", low_memory=False)
df2020_10 = pd.DataFrame(csv2020_10)
csv2020_11 = pd.read_csv("../RawData/CSVs/202011-citibike-tripdata.csv", low_memory=False)
df2020_11 = pd.DataFrame(csv2020_11)
csv2020_12 = pd.read_csv("../RawData/CSVs/202012-citibike-tripdata.csv", low_memory=False)
df2020_12 = pd.DataFrame(csv2020_12)
csv2021_01 = pd.read_csv("../RawData/CSVs/202101-citibike-tripdata.csv", low_memory=False)
df2021_01 = pd.DataFrame(csv2021_01)
df2020_2021_01 = pd.concat([df2020_12, df2020_11, df2020_10, df2020_09, df2020_08, df2020_07, df2020_06, df2020_05, df2020_04, df2020_03, df2020_02, df2020_01, df2021_01])
df2020_2021_01 = df2020_2021_01.dropna()
df2020_2021_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1          4131  2020-12-01 00:00:09.1730  2020-12-01 01:09:00.2370
# 2          1368  2020-12-01 00:00:28.7470  2020-12-01 00:23:16.9980
# 3          1707  2020-12-01 00:00:34.7680  2020-12-01 00:29:02.6470
# 4          2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
#
#    start station id           start station name  start station latitude  \
# 0              4065     Wadsworth Ave & W 179 St               40.848467
# 1              3284           E 88 St & Park Ave               40.781411
# 2              3443              W 52 St & 6 Ave               40.761330
# 3                72             W 52 St & 11 Ave               40.767272
# 4              3165  Central Park West & W 72 St               40.775794
#
#    start station longitude  end station id          end station name  \
# ...

# %%
csv2021_02 = pd.read_csv("../RawData/CSVs/202102-citibike-tripdata.csv", low_memory=False)
df2021_02 = pd.DataFrame(csv2021_02)
csv2021_03 = pd.read_csv("../RawData/CSVs/202103-citibike-tripdata.csv", low_memory=False)
df2021_03 = pd.DataFrame(csv2021_03)
csv2021_04 = pd.read_csv("../RawData/CSVs/202104-citibike-tripdata.csv", low_memory=False)
df2021_04 = pd.DataFrame(csv2021_04)
csv2021_05 = pd.read_csv("../RawData/CSVs/202105-citibike-tripdata.csv", low_memory=False)
df2021_05 = pd.DataFrame(csv2021_05)
csv2021_06 = pd.read_csv("../RawData/CSVs/202106-citibike-tripdata.csv", low_memory=False)
df2021_06 = pd.DataFrame(csv2021_06)
df2021_NO_01 = pd.concat([df2021_06, df2021_05, df2021_04, df2021_03, df2021_02])
df2021_NO_01 = df2021_NO_01.dropna()
df2021_NO_01.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  6339C86D47EC0FAB   docked_bike  2021-06-02 17:18:45  2021-06-02 17:26:17
# 1  CDE3C147775B4002   docked_bike  2021-06-04 21:01:46  2021-06-04 21:32:09
# 2  D335C3F6B412B846   docked_bike  2021-06-15 16:39:36  2021-06-15 16:55:02
# 3  8DA6810777C89735   docked_bike  2021-06-08 11:36:40  2021-06-08 11:39:41
# 4  62D9B66A3A1D9FDF   docked_bike  2021-06-18 12:48:43  2021-06-18 13:04:14
#
#       start_station_name start_station_id       end_station_name  \
# 0        W 51 St & 6 Ave           6740.1  E 66 St & Madison Ave
# 1       W 56 St & 10 Ave          6955.01      E 9 St & Avenue C
# 2  E 56 St & Madison Ave          6732.01        E 16 St & 5 Ave
# 3        E 68 St & 3 Ave          6896.16        1 Ave & E 62 St
# 4        E 48 St & 5 Ave          6626.01        W 20 St & 8 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
csvJC2015_09 = pd.read_csv("../RawData/CSVs/JC-201509-citibike-tripdata.csv", low_memory=False)
dfJC2015_09 = pd.DataFrame(csvJC2015_09)
csvJC2015_10 = pd.read_csv("../RawData/CSVs/JC-201510-citibike-tripdata.csv", low_memory=False)
dfJC2015_10 = pd.DataFrame(csvJC2015_10)
csvJC2015_11 = pd.read_csv("../RawData/CSVs/JC-201511-citibike-tripdata.csv", low_memory=False)
dfJC2015_11 = pd.DataFrame(csvJC2015_11)
dfJC2015 = pd.concat([dfJC2015_11, dfJC2015_10, dfJC2015_09])
dfJC2015 = dfJC2015.dropna()
dfJC2015 = dfJC2015.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
dfJC2015.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           141  2015-11-01 00:05:00  2015-11-01 00:07:21              3185
# 1           487  2015-11-01 00:05:34  2015-11-01 00:13:41              3186
# 2           153  2015-11-01 00:21:15  2015-11-01 00:23:48              3202
# 3           196  2015-11-01 01:11:31  2015-11-01 01:14:47              3205
# 4           724  2015-11-01 01:14:52  2015-11-01 01:26:56              3202
#
#   start station name  start station latitude  start station longitude  \
# 0          City Hall               40.717733               -74.043845
# 1      Grove St PATH               40.719586               -74.043117
# 2       Newport PATH               40.727224               -74.033759
# 3  JC Medical Center               40.716540               -74.049638
# 4       Newport PATH               40.727224               -74.033759
#
#    end station id   end station name  end station latitude  \
# ...

# %%
csvJC2016_01 = pd.read_csv("../RawData/CSVs/JC-20161-citibike-tripdata.csv", low_memory=False)
dfJC2016_01 = pd.DataFrame(csvJC2016_01)
csvJC2016_02 = pd.read_csv("../RawData/CSVs/JC-20162-citibike-tripdata.csv", low_memory=False)
dfJC2016_02 = pd.DataFrame(csvJC2016_02)
csvJC2016_03 = pd.read_csv("../RawData/CSVs/JC-20163-citibike-tripdata.csv", low_memory=False)
dfJC2016_03 = pd.DataFrame(csvJC2016_03)
csvJC2016_04 = pd.read_csv("../RawData/CSVs/JC-201604-citibike-tripdata.csv", low_memory=False)
dfJC2016_04 = pd.DataFrame(csvJC2016_04)
csvJC2016_05 = pd.read_csv("../RawData/CSVs/JC-201605-citibike-tripdata.csv", low_memory=False)
dfJC2016_05 = pd.DataFrame(csvJC2016_05)
csvJC2016_06 = pd.read_csv("../RawData/CSVs/JC-201606-citibike-tripdata.csv", low_memory=False)
dfJC2016_06 = pd.DataFrame(csvJC2016_06)
csvJC2016_07 = pd.read_csv("../RawData/CSVs/JC-201607-citibike-tripdata.csv", low_memory=False)
dfJC2016_07 = pd.DataFrame(csvJC2016_07)
csvJC2016_08 = pd.read_csv("../RawData/CSVs/JC-201608-citibike-tripdata.csv", low_memory=False)
dfJC2016_08 = pd.DataFrame(csvJC2016_08)
csvJC2016_09 = pd.read_csv("../RawData/CSVs/JC-201609-citibike-tripdata.csv", low_memory=False)
dfJC2016_09 = pd.DataFrame(csvJC2016_09)
csvJC2016_10 = pd.read_csv("../RawData/CSVs/JC-201610-citibike-tripdata.csv", low_memory=False)
dfJC2016_10 = pd.DataFrame(csvJC2016_10)
csvJC2016_11 = pd.read_csv("../RawData/CSVs/JC-201611-citibike-tripdata.csv", low_memory=False)
dfJC2016_11 = pd.DataFrame(csvJC2016_11)
csvJC2016_12 = pd.read_csv("../RawData/CSVs/JC-201612-citibike-tripdata.csv", low_memory=False)
dfJC2016_12 = pd.DataFrame(csvJC2016_12)
dfJC2016 = pd.concat([dfJC2016_12, dfJC2016_11, dfJC2016_10, dfJC2016_09, dfJC2016_08, dfJC2016_07, dfJC2016_06, dfJC2016_05, dfJC2016_04, dfJC2016_03, dfJC2016_02, dfJC2016_01])
dfJC2016 = dfJC2016.dropna()
dfJC2016 = dfJC2016.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
dfJC2016.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           204  2016-12-01 00:33:31  2016-12-01 00:36:55              3186
# 1           606  2016-12-01 00:56:09  2016-12-01 01:06:16              3194
# 2           185  2016-12-01 01:14:22  2016-12-01 01:17:27              3186
# 3           504  2016-12-01 01:29:52  2016-12-01 01:38:17              3194
# 4           672  2016-12-01 01:47:14  2016-12-01 01:58:27              3186
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1    McGinley Square               40.725340               -74.067622
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4      Grove St PATH               40.719586               -74.043117
#
#    end station id      end station name  end station latitude  \
# ...

# %%
csvJC2017_01 = pd.read_csv("../RawData/CSVs/JC-201701-citibike-tripdata.csv", low_memory=False)
dfJC2017_01 = pd.DataFrame(csvJC2017_01)
dfJC2017_01 = dfJC2017_01.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csvJC2017_02 = pd.read_csv("../RawData/CSVs/JC-201702-citibike-tripdata.csv", low_memory=False)
dfJC2017_02 = pd.DataFrame(csvJC2017_02)
dfJC2017_02 = dfJC2017_02.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csvJC2017_03 = pd.read_csv("../RawData/CSVs/JC-201703-citibike-tripdata.csv", low_memory=False)
dfJC2017_03 = pd.DataFrame(csvJC2017_03)
dfJC2017_03 = dfJC2017_03.rename(columns={'Trip Duration': 'tripduration', 'Start Time': 'starttime', 'Stop Time': 'stoptime', 
                          'Start Station ID': 'start station id', 'Start Station Name': 'start station name', 
                          'Start Station Latitude': 'start station latitude', 'Start Station Longitude': 'start station longitude',
                          'End Station ID': 'end station id', 'End Station Name': 'end station name', 
                          'End Station Latitude': 'end station latitude', 'End Station Longitude': 'end station longitude', 
                          'Bike ID': 'bikeid', 'User Type': 'usertype','Birth Year': 'birth year', 'Gender': 'gender'})
csvJC2017_04 = pd.read_csv("../RawData/CSVs/JC-201704-citibike-tripdata.csv", low_memory=False)
dfJC2017_04 = pd.DataFrame(csvJC2017_04)
csvJC2017_05 = pd.read_csv("../RawData/CSVs/JC-201705-citibike-tripdata.csv", low_memory=False)
dfJC2017_05 = pd.DataFrame(csvJC2017_05)
csvJC2017_06 = pd.read_csv("../RawData/CSVs/JC-201706-citibike-tripdata.csv", low_memory=False)
dfJC2017_06 = pd.DataFrame(csvJC2017_06)
csvJC2017_07 = pd.read_csv("../RawData/CSVs/JC-201707-citibike-tripdata.csv", low_memory=False)
dfJC2017_07 = pd.DataFrame(csvJC2017_07)
csvJC2017_08 = pd.read_csv("../RawData/CSVs/JC-201708-citibike-tripdata.csv", low_memory=False)
dfJC2017_08 = pd.DataFrame(csvJC2017_08)
csvJC2017_09 = pd.read_csv("../RawData/CSVs/JC-201709-citibike-tripdata.csv", low_memory=False)
dfJC2017_09 = pd.DataFrame(csvJC2017_09)
csvJC2017_10 = pd.read_csv("../RawData/CSVs/JC-201710-citibike-tripdata.csv", low_memory=False)
dfJC2017_10 = pd.DataFrame(csvJC2017_10)
csvJC2017_11 = pd.read_csv("../RawData/CSVs/JC-201711-citibike-tripdata.csv", low_memory=False)
dfJC2017_11 = pd.DataFrame(csvJC2017_11)
csvJC2017_12 = pd.read_csv("../RawData/CSVs/JC-201712-citibike-tripdata.csv", low_memory=False)
dfJC2017_12 = pd.DataFrame(csvJC2017_12)
dfJC2017 = pd.concat([dfJC2017_12, dfJC2017_11, dfJC2017_10, dfJC2017_09, dfJC2017_08, dfJC2017_07, dfJC2017_06, dfJC2017_05, dfJC2017_04, dfJC2017_03, dfJC2017_02, dfJC2017_01])
dfJC2017 = dfJC2017.dropna()
dfJC2017.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55              3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57              3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13              3194
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    end station id      end station name  end station latitude  \
# ...

# %%
csvJC2018_01 = pd.read_csv("../RawData/CSVs/JC-201801-citibike-tripdata.csv", low_memory=False)
dfJC2018_01 = pd.DataFrame(csvJC2018_01)
csvJC2018_02 = pd.read_csv("../RawData/CSVs/JC-201802-citibike-tripdata.csv", low_memory=False)
dfJC2018_02 = pd.DataFrame(csvJC2018_02)
csvJC2018_03 = pd.read_csv("../RawData/CSVs/JC-201803-citibike-tripdata.csv", low_memory=False)
dfJC2018_03 = pd.DataFrame(csvJC2018_03)
csvJC2018_04 = pd.read_csv("../RawData/CSVs/JC-201804-citibike-tripdata.csv", low_memory=False)
dfJC2018_04 = pd.DataFrame(csvJC2018_04)
csvJC2018_05 = pd.read_csv("../RawData/CSVs/JC-201805-citibike-tripdata.csv", low_memory=False)
dfJC2018_05 = pd.DataFrame(csvJC2018_05)
csvJC2018_06 = pd.read_csv("../RawData/CSVs/JC-201806-citibike-tripdata.csv", low_memory=False)
dfJC2018_06 = pd.DataFrame(csvJC2018_06)
csvJC2018_07 = pd.read_csv("../RawData/CSVs/JC-201807-citibike-tripdata.csv", low_memory=False)
dfJC2018_07 = pd.DataFrame(csvJC2018_07)
csvJC2018_08 = pd.read_csv("../RawData/CSVs/JC-201808-citibike-tripdata.csv", low_memory=False)
dfJC2018_08 = pd.DataFrame(csvJC2018_08)
csvJC2018_09 = pd.read_csv("../RawData/CSVs/JC-201809-citibike-tripdata.csv", low_memory=False)
dfJC2018_09 = pd.DataFrame(csvJC2018_09)
csvJC2018_10 = pd.read_csv("../RawData/CSVs/JC-201810-citibike-tripdata.csv", low_memory=False)
dfJC2018_10 = pd.DataFrame(csvJC2018_10)
csvJC2018_11 = pd.read_csv("../RawData/CSVs/JC-201811-citibike-tripdata.csv", low_memory=False)
dfJC2018_11 = pd.DataFrame(csvJC2018_11)
csvJC2018_12 = pd.read_csv("../RawData/CSVs/JC-201812-citibike-tripdata.csv", low_memory=False)
dfJC2018_12 = pd.DataFrame(csvJC2018_12)
dfJC2018 = pd.concat([dfJC2018_12, dfJC2018_11, dfJC2018_10, dfJC2018_09, dfJC2018_08, dfJC2018_07, dfJC2018_06, dfJC2018_05, dfJC2018_04, dfJC2018_03, dfJC2018_02, dfJC2018_01])
dfJC2018 = dfJC2018.dropna()
dfJC2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           170  2018-12-01 00:03:53.3860  2018-12-01 00:06:43.7160
# 1           172  2018-12-01 00:47:13.7340  2018-12-01 00:50:05.8160
# 2           247  2018-12-01 00:48:57.6960  2018-12-01 00:53:05.6780
# 3           406  2018-12-01 01:33:53.6630  2018-12-01 01:40:39.7480
# 4           354  2018-12-01 06:26:52.5120  2018-12-01 06:32:46.5170
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3214  Essex Light Rail
# ...

# %%
csvJC2019_01 = pd.read_csv("../RawData/CSVs/JC-201901-citibike-tripdata.csv", low_memory=False)
dfJC2019_01 = pd.DataFrame(csvJC2019_01)
csvJC2019_02 = pd.read_csv("../RawData/CSVs/JC-201902-citibike-tripdata.csv", low_memory=False)
dfJC2019_02 = pd.DataFrame(csvJC2019_02)
csvJC2019_03 = pd.read_csv("../RawData/CSVs/JC-201903-citibike-tripdata.csv", low_memory=False)
dfJC2019_03 = pd.DataFrame(csvJC2019_03)
csvJC2019_04 = pd.read_csv("../RawData/CSVs/JC-201904-citibike-tripdata.csv", low_memory=False)
dfJC2019_04 = pd.DataFrame(csvJC2019_04)
csvJC2019_05 = pd.read_csv("../RawData/CSVs/JC-201905-citibike-tripdata.csv", low_memory=False)
dfJC2019_05 = pd.DataFrame(csvJC2019_05)
csvJC2019_06 = pd.read_csv("../RawData/CSVs/JC-201906-citibike-tripdata.csv", low_memory=False)
dfJC2019_06 = pd.DataFrame(csvJC2019_06)
csvJC2019_07 = pd.read_csv("../RawData/CSVs/JC-201907-citibike-tripdata.csv", low_memory=False)
dfJC2019_07 = pd.DataFrame(csvJC2019_07)
csvJC2019_08 = pd.read_csv("../RawData/CSVs/JC-201908-citibike-tripdata.csv", low_memory=False)
dfJC2019_08 = pd.DataFrame(csvJC2019_08)
csvJC2019_09 = pd.read_csv("../RawData/CSVs/JC-201909-citibike-tripdata.csv", low_memory=False)
dfJC2019_09 = pd.DataFrame(csvJC2019_09)
csvJC2019_10 = pd.read_csv("../RawData/CSVs/JC-201910-citibike-tripdata.csv", low_memory=False)
dfJC2019_10 = pd.DataFrame(csvJC2019_10)
csvJC2019_11 = pd.read_csv("../RawData/CSVs/JC-201911-citibike-tripdata.csv", low_memory=False)
dfJC2019_11 = pd.DataFrame(csvJC2019_11)
csvJC2019_12 = pd.read_csv("../RawData/CSVs/JC-201912-citibike-tripdata.csv", low_memory=False)
dfJC2019_12 = pd.DataFrame(csvJC2019_12)
dfJC2019 = pd.concat([dfJC2019_12, dfJC2019_11, dfJC2019_10, dfJC2019_09, dfJC2019_08, dfJC2019_07, dfJC2019_06, dfJC2019_05, dfJC2019_04, dfJC2019_03, dfJC2019_02, dfJC2019_01])
dfJC2019 = dfJC2019.dropna()
dfJC2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
csvJC2020_01 = pd.read_csv("../RawData/CSVs/JC-202001-citibike-tripdata.csv", low_memory=False)
dfJC2020_01 = pd.DataFrame(csvJC2020_01)
csvJC2020_02 = pd.read_csv("../RawData/CSVs/JC-202002-citibike-tripdata.csv", low_memory=False)
dfJC2020_02 = pd.DataFrame(csvJC2020_02)
csvJC2020_03 = pd.read_csv("../RawData/CSVs/JC-202003-citibike-tripdata.csv", low_memory=False)
dfJC2020_03 = pd.DataFrame(csvJC2020_03)
csvJC2020_04 = pd.read_csv("../RawData/CSVs/JC-202004-citibike-tripdata.csv", low_memory=False)
dfJC2020_04 = pd.DataFrame(csvJC2020_04)
csvJC2020_05 = pd.read_csv("../RawData/CSVs/JC-202005-citibike-tripdata.csv", low_memory=False)
dfJC2020_05 = pd.DataFrame(csvJC2020_05)
csvJC2020_06 = pd.read_csv("../RawData/CSVs/JC-202006-citibike-tripdata.csv", low_memory=False)
dfJC2020_06 = pd.DataFrame(csvJC2020_06)
csvJC2020_07 = pd.read_csv("../RawData/CSVs/JC-202007-citibike-tripdata.csv", low_memory=False)
dfJC2020_07 = pd.DataFrame(csvJC2020_07)
csvJC2020_08 = pd.read_csv("../RawData/CSVs/JC-202008-citibike-tripdata.csv", low_memory=False)
dfJC2020_08 = pd.DataFrame(csvJC2020_08)
csvJC2020_09 = pd.read_csv("../RawData/CSVs/JC-202009-citibike-tripdata.csv", low_memory=False)
dfJC2020_09 = pd.DataFrame(csvJC2020_09)
csvJC2020_10 = pd.read_csv("../RawData/CSVs/JC-202010-citibike-tripdata.csv", low_memory=False)
dfJC2020_10 = pd.DataFrame(csvJC2020_10)
csvJC2020_11 = pd.read_csv("../RawData/CSVs/JC-202011-citibike-tripdata.csv", low_memory=False)
dfJC2020_11 = pd.DataFrame(csvJC2020_11)
csvJC2020_12 = pd.read_csv("../RawData/CSVs/JC-202012-citibike-tripdata.csv", low_memory=False)
dfJC2020_12 = pd.DataFrame(csvJC2020_12)
csvJC2021_01 = pd.read_csv("../RawData/CSVs/JC-202101-citibike-tripdata.csv", low_memory=False)
dfJC2021_01 = pd.DataFrame(csvJC2021_01)
dfJC2020_2021_01 = pd.concat([dfJC2020_12, dfJC2020_11, dfJC2020_10, dfJC2020_09, dfJC2020_08, dfJC2020_07, dfJC2020_06, dfJC2020_05, dfJC2020_04, dfJC2020_03, dfJC2020_02, dfJC2020_01, dfJC2021_01])
dfJC2020_2021_01 = dfJC2020_2021_01.dropna()
dfJC2020_2021_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1           572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2           387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3           188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4           594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    start station longitude  end station id end station name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
csvJC2021_02 = pd.read_csv("../RawData/CSVs/JC-202102-citibike-tripdata.csv", low_memory=False)
dfJC2021_02 = pd.DataFrame(csvJC2021_02)
csvJC2021_03 = pd.read_csv("../RawData/CSVs/JC-202103-citibike-tripdata.csv", low_memory=False)
dfJC2021_03 = pd.DataFrame(csvJC2021_03)
csvJC2021_04 = pd.read_csv("../RawData/CSVs/JC-202104-citibike-tripdata.csv", low_memory=False)
dfJC2021_04 = pd.DataFrame(csvJC2021_04)
csvJC2021_05 = pd.read_csv("../RawData/CSVs/JC-202105-citibike-tripdata.csv", low_memory=False)
dfJC2021_05 = pd.DataFrame(csvJC2021_05)
csvJC2021_06 = pd.read_csv("../RawData/CSVs/JC-202106-citibike-tripdata.csv", low_memory=False)
dfJC2021_06 = pd.DataFrame(csvJC2021_06)
dfJC2021_NO_01 = pd.concat([dfJC2021_06, dfJC2021_05, dfJC2021_04, dfJC2021_03, dfJC2021_02])
dfJC2021_NO_01 = dfJC2021_NO_01.dropna()
dfJC2021_NO_01.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  6457BC38526A4187   docked_bike  2021-06-21 10:19:04  2021-06-21 10:26:28
# 1  508AC0C37B2BE1A8   docked_bike  2021-06-05 10:12:18  2021-06-05 10:27:10
# 2  A1AD52779E13308C   docked_bike  2021-06-04 15:42:35  2021-06-04 15:54:28
# 3  DA8AA7083ACCA940   docked_bike  2021-06-03 18:07:42  2021-06-03 19:09:26
# 4  BF8DB08AEF78C8D1   docked_bike  2021-06-05 15:39:56  2021-06-05 16:16:09
#
#                        start_station_name start_station_id  \
# 0                          Lafayette Park            JC078
# 1  Mama Johnson Field - 4 St & Jackson St            HB404
# 2                            Lincoln Park            JC053
# 3       Columbus Park - Clinton St & 9 St            HB501
# 4       Columbus Park - Clinton St & 9 St            HB501
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0                          City Hall          JC003  40.713463 -74.062858
# ...

# %%
all2021_NO_01df = pd.concat([dfJC2021_NO_01, df2021_NO_01])
all2021_NO_01df
# Out:
#                  ride_id rideable_type           started_at  \
# 0       6457BC38526A4187   docked_bike  2021-06-21 10:19:04
# 1       508AC0C37B2BE1A8   docked_bike  2021-06-05 10:12:18
# 2       A1AD52779E13308C   docked_bike  2021-06-04 15:42:35
# 3       DA8AA7083ACCA940   docked_bike  2021-06-03 18:07:42
# 4       BF8DB08AEF78C8D1   docked_bike  2021-06-05 15:39:56
# ...                  ...           ...                  ...
# 649978  84DA58E73B2DF079   docked_bike  2021-02-12 16:01:17
# 649979  3A14299B4F7FA1CF   docked_bike  2021-02-17 18:03:24
# 649980  7B86EE3DC7E026BC   docked_bike  2021-02-28 18:58:31
# 649981  D665B8623FC01285   docked_bike  2021-02-25 09:00:41
# 649982  08A07BB378B0FE2F   docked_bike  2021-02-08 13:31:57
#
#                    ended_at                      start_station_name  \
# 0       2021-06-21 10:26:28                          Lafayette Park
# 1       2021-06-05 10:27:10  Mama Johnson Field - 4 St & Jackson St
# ...

# %%
all2020_2021_01df = pd.concat([dfJC2020_2021_01, df2020_2021_01])
all2020_2021_01df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1                 572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2                 387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3                 188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4                 594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
# ...               ...                       ...                       ...
# 1095341           569  2021-01-31 23:54:00.3610  2021-02-01 00:03:29.8190
# 1095342          1439  2021-01-31 23:55:50.4170  2021-02-01 00:19:49.8980
# 1095343          2619  2021-01-31 23:56:14.9540  2021-02-01 00:39:54.3500
# 1095344            83  2021-01-31 23:59:19.8260  2021-02-01 00:00:43.5840
# 1095345          1313  2021-01-31 23:59:40.4440  2021-02-01 00:21:33.8470
#
#          start station id         start station name  start station latitude  \
# ...

# %%
all2019df = pd.concat([dfJC2019, df2019])
all2019df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1                416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2                294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3                 97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4                286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id         start station name  start station latitude  \
# ...

# %%
all2018df = pd.concat([dfJC2018, df2018])
all2018df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                170  2018-12-01 00:03:53.3860  2018-12-01 00:06:43.7160
# 1                172  2018-12-01 00:47:13.7340  2018-12-01 00:50:05.8160
# 2                247  2018-12-01 00:48:57.6960  2018-12-01 00:53:05.6780
# 3                406  2018-12-01 01:33:53.6630  2018-12-01 01:40:39.7480
# 4                354  2018-12-01 06:26:52.5120  2018-12-01 06:32:46.5170
# ...              ...                       ...                       ...
# 718989           843  2018-01-31 17:28:27.5390  2018-01-31 17:42:30.5890
# 718990           244  2018-01-31 17:34:20.4510  2018-01-31 17:38:24.7200
# 718991           302  2018-01-31 18:20:55.5430  2018-01-31 18:25:58.3350
# 718992           222  2018-01-31 18:47:42.5720  2018-01-31 18:51:24.6830
# 718993           713  2018-01-31 19:35:55.4840  2018-01-31 19:47:48.6400
#
#         start station id             start station name  \
# ...

# %%
all2017df = pd.concat([dfJC2017, df2017])
all2017df
# Out:
#         tripduration            starttime             stoptime  \
# 0                452  2017-12-01 00:00:59  2017-12-01 00:08:32
# 1                159  2017-12-01 00:04:42  2017-12-01 00:07:21
# 2                175  2017-12-01 00:17:00  2017-12-01 00:19:55
# 3                455  2017-12-01 00:50:22  2017-12-01 00:57:57
# 4                670  2017-12-01 00:55:03  2017-12-01 01:06:13
# ...              ...                  ...                  ...
# 726671           340  2017-01-31 23:59:14  2017-02-01 00:04:55
# 726672           338  2017-01-31 23:59:23  2017-02-01 00:05:01
# 726673            79  2017-01-27 04:59:49  2017-01-27 05:01:08
# 726674           711  2017-01-27 06:23:29  2017-01-27 06:35:21
# 726675           623  2017-01-27 06:36:39  2017-01-27 06:47:02
#
#         start station id       start station name  start station latitude  \
# 0                   3183           Exchange Place               40.716247
# ...

# %%
all2016df = pd.concat([dfJC2016, df2016])
all2016df
# Out:
#         tripduration            starttime             stoptime  \
# 0                204  2016-12-01 00:33:31  2016-12-01 00:36:55
# 1                606  2016-12-01 00:56:09  2016-12-01 01:06:16
# 2                185  2016-12-01 01:14:22  2016-12-01 01:17:27
# 3                504  2016-12-01 01:29:52  2016-12-01 01:38:17
# 4                672  2016-12-01 01:47:14  2016-12-01 01:58:27
# ...              ...                  ...                  ...
# 509473          1275   1/31/2016 23:58:20    2/1/2016 00:19:36
# 509474          1576   1/31/2016 23:58:39    2/1/2016 00:24:55
# 509475           356   1/31/2016 23:58:54    2/1/2016 00:04:51
# 509476          1128   1/31/2016 23:59:13    2/1/2016 00:18:02
# 509477           851   1/31/2016 23:59:26    2/1/2016 00:13:38
#
#         start station id     start station name  start station latitude  \
# 0                   3186          Grove St PATH               40.719586
# ...

# %%
all2015df = pd.concat([dfJC2015, df2015])
all2015df
# Out:
#         tripduration            starttime             stoptime  \
# 0                141  2015-11-01 00:05:00  2015-11-01 00:07:21
# 1                487  2015-11-01 00:05:34  2015-11-01 00:13:41
# 2                153  2015-11-01 00:21:15  2015-11-01 00:23:48
# 3                196  2015-11-01 01:11:31  2015-11-01 01:14:47
# 4                724  2015-11-01 01:14:52  2015-11-01 01:26:56
# ...              ...                  ...                  ...
# 285547           169      1/31/2015 23:57        2/1/2015 0:00
# 285548           827      1/31/2015 23:58        2/1/2015 0:12
# 285549           798      1/31/2015 23:58        2/1/2015 0:11
# 285550           725      1/31/2015 23:58        2/1/2015 0:10
# 285551           892      1/31/2015 23:59        2/1/2015 0:14
#
#         start station id            start station name  \
# 0                   3185                     City Hall
# 1                   3186                 Grove St PATH
# ...

# %%
alldf_JUST01_2021 = pd.concat([all2013df, all2014df, all2015df, all2016df, all2017df, all2018df, all2019df, all2020_2021_01df])
alldf_JUST01_2021
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1015       2013-12-01 00:00:03       2013-12-01 00:16:58
# 1                 962       2013-12-01 00:00:07       2013-12-01 00:16:09
# 2                 768       2013-12-01 00:00:15       2013-12-01 00:13:03
# 3                 218       2013-12-01 00:00:49       2013-12-01 00:04:27
# 4                 550       2013-12-01 00:01:28       2013-12-01 00:10:38
# ...               ...                       ...                       ...
# 1095341           569  2021-01-31 23:54:00.3610  2021-02-01 00:03:29.8190
# 1095342          1439  2021-01-31 23:55:50.4170  2021-02-01 00:19:49.8980
# 1095343          2619  2021-01-31 23:56:14.9540  2021-02-01 00:39:54.3500
# 1095344            83  2021-01-31 23:59:19.8260  2021-02-01 00:00:43.5840
# 1095345          1313  2021-01-31 23:59:40.4440  2021-02-01 00:21:33.8470
#
#          start station id         start station name  start station latitude  \
# ...

# %%
# Main dfs: alldf_JUST01_2021, all2021_NO_01df

# %%
alldf_JUST01_2021.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
all2021_NO_01df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
oldLatLongdf = alldf_JUST01_2021[['starttime', 'stoptime', 'start station latitude', 'start station longitude', 'start station name', 'end station latitude', 'end station longitude', 'end station name']]
oldLatLongdf = oldLatLongdf.rename(columns={'end station name':'end_station_name', 'start station name':'start_station_name', 'starttime':'started_at', 'stoptime':'ended_at', 'start station latitude':'start_lat', 'start station longitude':'start_lng', 'end station latitude':'end_lat', 'end station longitude':'end_lng'})
oldLatLongdf
# Out:
#                        started_at                  ended_at  start_lat  \
# 0             2013-12-01 00:00:03       2013-12-01 00:16:58  40.720196
# 1             2013-12-01 00:00:07       2013-12-01 00:16:09  40.722055
# 2             2013-12-01 00:00:15       2013-12-01 00:13:03  40.729538
# 3             2013-12-01 00:00:49       2013-12-01 00:04:27  40.759291
# 4             2013-12-01 00:01:28       2013-12-01 00:10:38  40.726281
# ...                           ...                       ...        ...
# 1095341  2021-01-31 23:54:00.3610  2021-02-01 00:03:29.8190  40.665147
# 1095342  2021-01-31 23:55:50.4170  2021-02-01 00:19:49.8980  40.711863
# 1095343  2021-01-31 23:56:14.9540  2021-02-01 00:39:54.3500  40.763707
# 1095344  2021-01-31 23:59:19.8260  2021-02-01 00:00:43.5840  40.751184
# 1095345  2021-01-31 23:59:40.4440  2021-02-01 00:21:33.8470  40.732219
#
#          start_lng         start_station_name    end_lat    end_lng  \
# ...

# %%
newLatLongdf = all2021_NO_01df[['started_at', 'ended_at', 'start_lat', 'start_lng', 'start_station_name', 'end_lat', 'end_lng', 'end_station_name']]
newLatLongdf
# Out:
#                  started_at             ended_at  start_lat  start_lng  \
# 0       2021-06-21 10:19:04  2021-06-21 10:26:28  40.713463 -74.062858
# 1       2021-06-05 10:12:18  2021-06-05 10:27:10  40.743139 -74.040040
# 2       2021-06-04 15:42:35  2021-06-04 15:54:28  40.724605 -74.078405
# 3       2021-06-03 18:07:42  2021-06-03 19:09:26  40.748161 -74.032453
# 4       2021-06-05 15:39:56  2021-06-05 16:16:09  40.748161 -74.032453
# ...                     ...                  ...        ...        ...
# 649978  2021-02-12 16:01:17  2021-02-12 16:13:53  40.702700 -73.920950
# 649979  2021-02-17 18:03:24  2021-02-17 18:06:39  40.755102 -73.974986
# 649980  2021-02-28 18:58:31  2021-02-28 19:12:51  40.696710 -73.928070
# 649981  2021-02-25 09:00:41  2021-02-25 09:13:56  40.676368 -73.952918
# 649982  2021-02-08 13:31:57  2021-02-08 13:50:45  40.675146 -73.975232
#
#                             start_station_name    end_lat    end_lng  \
# ...

# %%
latLngdf = pd.concat([oldLatLongdf, newLatLongdf], copy=False)
latLngdf
# Out:
#                  started_at             ended_at  start_lat  start_lng  \
# 0       2013-12-01 00:00:03  2013-12-01 00:16:58  40.720196 -73.989978
# 1       2013-12-01 00:00:07  2013-12-01 00:16:09  40.722055 -73.989111
# 2       2013-12-01 00:00:15  2013-12-01 00:13:03  40.729538 -73.984267
# 3       2013-12-01 00:00:49  2013-12-01 00:04:27  40.759291 -73.988597
# 4       2013-12-01 00:01:28  2013-12-01 00:10:38  40.726281 -73.989780
# ...                     ...                  ...        ...        ...
# 649978  2021-02-12 16:01:17  2021-02-12 16:13:53  40.702700 -73.920950
# 649979  2021-02-17 18:03:24  2021-02-17 18:06:39  40.755102 -73.974986
# 649980  2021-02-28 18:58:31  2021-02-28 19:12:51  40.696710 -73.928070
# 649981  2021-02-25 09:00:41  2021-02-25 09:13:56  40.676368 -73.952918
# 649982  2021-02-08 13:31:57  2021-02-08 13:50:45  40.675146 -73.975232
#
#               start_station_name    end_lat    end_lng  \
# 0        Allen St & Rivington St  40.743943 -73.979661
# ...

# %%
latLngdf['started_at'] = pd.to_datetime(latLngdf['started_at'])

# %%
latLngdf['ended_at'] = pd.to_datetime(latLngdf['ended_at'])

# %%
startLatLngdf = latLngdf.drop(columns=['end_lat', 'end_lng', 'end_station_name', 'ended_at'])
startLatLngdf = startLatLngdf.sort_values(by='started_at')
startLatLngdf['started_at'] = startLatLngdf['started_at'].dt.to_period('M')
startLatLngdf
# Out:
#         started_at  start_lat  start_lng          start_station_name
# 0          2013-06  40.742354 -73.989151          Broadway & W 24 St
# 1          2013-06  40.742354 -73.989151          Broadway & W 24 St
# 3          2013-06  40.735243 -73.987586         E 15 St & Irving Pl
# 4          2013-06  40.705693 -74.016777       Little West St & 1 Pl
# 6          2013-06  40.734546 -73.990741          Broadway & E 14 St
# ...            ...        ...        ...                         ...
# 2090081    2021-06  40.721700 -74.002381        Grand St & Greene St
# 152465     2021-06  40.810792 -73.943068        Lenox Ave & W 130 St
# 1331494    2021-06  40.737262 -73.992390             E 16 St & 5 Ave
# 2376122    2021-06  40.829608 -73.921461  Grand Concourse & E 164 St
# 1194165    2021-06  40.788130 -73.952060          E 98 St & Park Ave
#
# [119730612 rows x 4 columns]

# %%
startCountsLatLng = startLatLngdf.value_counts(['started_at', 'start_lat', 'start_lng'], sort=False)
startCountsLatLng
# Out:
# started_at  start_lat  start_lng
# 2013-06     40.646607  -74.015970    109
#             40.646768  -74.016510    245
#             40.680342  -73.955769    261
#             40.680983  -73.950048    379
#             40.682166  -73.953990    128
#                                     ...
# 2021-06     40.879350  -73.885340    418
#             40.880294  -73.886065     14
#                        -73.886065     79
#             40.880295  -73.886065      7
#             40.882260  -73.887020    291
# Length: 70928, dtype: int64

# %%
startCountsLatLngdf = pd.DataFrame(startCountsLatLng.reset_index())
startCountsLatLngdf.columns = ['monthYear', 'start_lat', 'start_lng', 'startCount']

startCountsLatLngdf
# Out:
#       monthYear  start_lat  start_lng  startCount
# 0       2013-06  40.646607 -74.015970         109
# 1       2013-06  40.646768 -74.016510         245
# 2       2013-06  40.680342 -73.955769         261
# 3       2013-06  40.680983 -73.950048         379
# 4       2013-06  40.682166 -73.953990         128
# ...         ...        ...        ...         ...
# 70923   2021-06  40.879350 -73.885340         418
# 70924   2021-06  40.880294 -73.886065          14
# 70925   2021-06  40.880294 -73.886065          79
# 70926   2021-06  40.880295 -73.886065           7
# 70927   2021-06  40.882260 -73.887020         291
#
# [70928 rows x 4 columns]

# %%
uniqueStartLatLngdf = startLatLngdf.drop_duplicates(subset=['started_at', 'start_lat', 'start_lng'])
uniqueStartLatLngdf
# Out:
#         started_at  start_lat  start_lng          start_station_name
# 0          2013-06  40.742354 -73.989151          Broadway & W 24 St
# 3          2013-06  40.735243 -73.987586         E 15 St & Irving Pl
# 4          2013-06  40.705693 -74.016777       Little West St & 1 Pl
# 6          2013-06  40.734546 -73.990741          Broadway & E 14 St
# 251        2013-06  40.726218 -73.983799           E 7 St & Avenue A
# ...            ...        ...        ...                         ...
# 2526276    2021-06  40.860479 -73.905717     Aqueduct Ave & North St
# 784106     2021-06  40.674340 -74.001947      Clinton St & Centre St
# 550762     2021-06  40.827134 -73.922736  Grand Concourse & E 161 St
# 500288     2021-06  40.763505 -73.971092       E 59 St & Madison Ave
# 2955129    2021-06  40.763505 -73.971092       E 59 St & Madison Ave
#
# [70928 rows x 4 columns]

# %%
uniqueStartLatLngdf = uniqueStartLatLngdf.rename(columns={'started_at':'monthYear'})
uniqueStartLatLngdf
# Out:
#         monthYear  start_lat  start_lng          start_station_name
# 0         2013-06  40.742354 -73.989151          Broadway & W 24 St
# 3         2013-06  40.735243 -73.987586         E 15 St & Irving Pl
# 4         2013-06  40.705693 -74.016777       Little West St & 1 Pl
# 6         2013-06  40.734546 -73.990741          Broadway & E 14 St
# 251       2013-06  40.726218 -73.983799           E 7 St & Avenue A
# ...           ...        ...        ...                         ...
# 2526276   2021-06  40.860479 -73.905717     Aqueduct Ave & North St
# 784106    2021-06  40.674340 -74.001947      Clinton St & Centre St
# 550762    2021-06  40.827134 -73.922736  Grand Concourse & E 161 St
# 500288    2021-06  40.763505 -73.971092       E 59 St & Madison Ave
# 2955129   2021-06  40.763505 -73.971092       E 59 St & Madison Ave
#
# [70928 rows x 4 columns]

# %%
uniqueStartLatLngdf = uniqueStartLatLngdf.merge(startCountsLatLngdf, how='outer', on=['start_lat', 'start_lng', 'monthYear'])
uniqueStartLatLngdf
# Out:
#       monthYear  start_lat  start_lng          start_station_name  startCount
# 0       2013-06  40.742354 -73.989151          Broadway & W 24 St        2574
# 1       2013-06  40.735243 -73.987586         E 15 St & Irving Pl        1328
# 2       2013-06  40.705693 -74.016777       Little West St & 1 Pl         563
# 3       2013-06  40.734546 -73.990741          Broadway & E 14 St        3119
# 4       2013-06  40.726218 -73.983799           E 7 St & Avenue A        1460
# ...         ...        ...        ...                         ...         ...
# 70923   2021-06  40.860479 -73.905717     Aqueduct Ave & North St           1
# 70924   2021-06  40.674340 -74.001947      Clinton St & Centre St           1
# 70925   2021-06  40.827134 -73.922736  Grand Concourse & E 161 St          45
# 70926   2021-06  40.763505 -73.971092       E 59 St & Madison Ave         105
# 70927   2021-06  40.763505 -73.971092       E 59 St & Madison Ave           1
#
# [70928 rows x 5 columns]

# %%
endLatLngdf = latLngdf.drop(columns=['start_lat', 'start_lng', 'start_station_name', 'started_at'])
endLatLngdf = endLatLngdf.sort_values(by='ended_at')
endLatLngdf['ended_at'] = endLatLngdf['ended_at'].dt.to_period('M')
endLatLngdf
# Out:
#         ended_at    end_lat    end_lng              end_station_name
# 3        2013-06  40.691782 -73.973730               Washington Park
# 7        2013-06  40.750967 -73.994442             8 Ave & W 31 St N
# 0        2013-06  40.743174 -74.003664               9 Ave & W 18 St
# 12       2013-06  40.682232 -73.961458         Fulton St & Grand Ave
# 1        2013-06  40.743174 -74.003664               9 Ave & W 18 St
# ...          ...        ...        ...                           ...
# 600387   2021-07  40.703276 -73.931835            Forrest WH station
# 123783   2021-07  40.847410 -73.911359       Townsend Ave & E 175 St
# 1589393  2021-07  40.874440 -73.891860  Bedford Park Blvd & Paul Ave
# 567544   2021-07  40.789622 -73.977570        W 87 St & West End Ave
# 1916284  2021-07  40.696102 -73.967510     Washington Ave & Park Ave
#
# [119730612 rows x 4 columns]

# %%
endCountsLatLng = endLatLngdf.value_counts(['ended_at', 'end_lat', 'end_lng'], sort=False)
endCountsLatLng
# Out:
# ended_at  end_lat    end_lng
# 2013-06   40.646607  -74.015970    100
#           40.646768  -74.016510    234
#           40.680342  -73.955769    410
#           40.680983  -73.950048    388
#           40.682166  -73.953990    118
#                                   ...
# 2021-07   40.863089  -73.917583      1
#           40.864632  -73.918598      1
#           40.867505  -73.926363      1
#           40.868140  -73.881450      3
#           40.874440  -73.891860      1
# Length: 71709, dtype: int64

# %%
endCountsLatLngdf = pd.DataFrame(endCountsLatLng.reset_index())
endCountsLatLngdf.columns = ['monthYear', 'end_lat', 'end_lng', 'endCount']

endCountsLatLngdf
# Out:
#       monthYear    end_lat    end_lng  endCount
# 0       2013-06  40.646607 -74.015970       100
# 1       2013-06  40.646768 -74.016510       234
# 2       2013-06  40.680342 -73.955769       410
# 3       2013-06  40.680983 -73.950048       388
# 4       2013-06  40.682166 -73.953990       118
# ...         ...        ...        ...       ...
# 71704   2021-07  40.863089 -73.917583         1
# 71705   2021-07  40.864632 -73.918598         1
# 71706   2021-07  40.867505 -73.926363         1
# 71707   2021-07  40.868140 -73.881450         3
# 71708   2021-07  40.874440 -73.891860         1
#
# [71709 rows x 4 columns]

# %%
endLatLngdf1 = endLatLngdf[0:59865305]
endLatLngdf2 = endLatLngdf[59865306:119730612]

# %%
uniqueEndLatLngdf1 = endLatLngdf1.drop_duplicates(subset=['ended_at', 'end_lat', 'end_lng'])
uniqueEndLatLngdf1
# Out:
#         ended_at    end_lat    end_lng        end_station_name
# 3        2013-06  40.691782 -73.973730         Washington Park
# 7        2013-06  40.750967 -73.994442       8 Ave & W 31 St N
# 0        2013-06  40.743174 -74.003664         9 Ave & W 18 St
# 12       2013-06  40.682232 -73.961458   Fulton St & Grand Ave
# 15       2013-06  40.728145 -73.990214  Shevchenko Pl & E 7 St
# ...          ...        ...        ...                     ...
# 336881   2018-08  40.677274 -73.982820        Union St & 4 Ave
# 337942   2018-08  40.763605 -73.989180         W 50 St & 9 Ave
# 1148321  2018-08  45.506364 -73.569463        8D QC Station 01
# 403535   2018-08  40.677165 -73.973828     Sterling Pl & 7 Ave
# 415593   2018-08  40.678612 -73.990373    Carroll St & Bond St
#
# [32505 rows x 4 columns]

# %%
uniqueEndLatLngdf2 = endLatLngdf2.drop_duplicates(subset=['ended_at', 'end_lat', 'end_lng'])
uniqueEndLatLngdf2
# Out:
#         ended_at    end_lat    end_lng              end_station_name
# 492308   2018-08  40.783964 -73.947167               2 Ave & E 96 St
# 495257   2018-08  40.737815 -73.999947               W 13 St & 7 Ave
# 495127   2018-08  40.778012 -73.954071               E 85 St & 3 Ave
# 495199   2018-08  40.750585 -73.994685               8 Ave & W 31 St
# 494057   2018-08  40.747804 -73.973442               E 39 St & 2 Ave
# ...          ...        ...        ...                           ...
# 600387   2021-07  40.703276 -73.931835            Forrest WH station
# 123783   2021-07  40.847410 -73.911359       Townsend Ave & E 175 St
# 1589393  2021-07  40.874440 -73.891860  Bedford Park Blvd & Paul Ave
# 567544   2021-07  40.789622 -73.977570        W 87 St & West End Ave
# 1916284  2021-07  40.696102 -73.967510     Washington Ave & Park Ave
#
# [40014 rows x 4 columns]

# %%
uniqueEndLatLngdf = pd.concat([uniqueEndLatLngdf1, uniqueEndLatLngdf2])
uniqueEndLatLngdf
# Out:
#         ended_at    end_lat    end_lng              end_station_name
# 3        2013-06  40.691782 -73.973730               Washington Park
# 7        2013-06  40.750967 -73.994442             8 Ave & W 31 St N
# 0        2013-06  40.743174 -74.003664               9 Ave & W 18 St
# 12       2013-06  40.682232 -73.961458         Fulton St & Grand Ave
# 15       2013-06  40.728145 -73.990214        Shevchenko Pl & E 7 St
# ...          ...        ...        ...                           ...
# 600387   2021-07  40.703276 -73.931835            Forrest WH station
# 123783   2021-07  40.847410 -73.911359       Townsend Ave & E 175 St
# 1589393  2021-07  40.874440 -73.891860  Bedford Park Blvd & Paul Ave
# 567544   2021-07  40.789622 -73.977570        W 87 St & West End Ave
# 1916284  2021-07  40.696102 -73.967510     Washington Ave & Park Ave
#
# [72519 rows x 4 columns]

# %%
uniqueEndLatLngdf = uniqueEndLatLngdf.rename(columns={'ended_at':'monthYear'})
uniqueEndLatLngdf
# Out:
#         monthYear    end_lat    end_lng              end_station_name
# 3         2013-06  40.691782 -73.973730               Washington Park
# 7         2013-06  40.750967 -73.994442             8 Ave & W 31 St N
# 0         2013-06  40.743174 -74.003664               9 Ave & W 18 St
# 12        2013-06  40.682232 -73.961458         Fulton St & Grand Ave
# 15        2013-06  40.728145 -73.990214        Shevchenko Pl & E 7 St
# ...           ...        ...        ...                           ...
# 600387    2021-07  40.703276 -73.931835            Forrest WH station
# 123783    2021-07  40.847410 -73.911359       Townsend Ave & E 175 St
# 1589393   2021-07  40.874440 -73.891860  Bedford Park Blvd & Paul Ave
# 567544    2021-07  40.789622 -73.977570        W 87 St & West End Ave
# 1916284   2021-07  40.696102 -73.967510     Washington Ave & Park Ave
#
# [72519 rows x 4 columns]

# %%
uniqueEndLatLngdf = uniqueEndLatLngdf.merge(endCountsLatLngdf, how='outer', on=['end_lat', 'end_lng', 'monthYear'])
uniqueEndLatLngdf
# Out:
#       monthYear    end_lat    end_lng              end_station_name  endCount
# 0       2013-06  40.691782 -73.973730               Washington Park       355
# 1       2013-06  40.750967 -73.994442             8 Ave & W 31 St N      2585
# 2       2013-06  40.743174 -74.003664               9 Ave & W 18 St      1040
# 3       2013-06  40.682232 -73.961458         Fulton St & Grand Ave       440
# 4       2013-06  40.728145 -73.990214        Shevchenko Pl & E 7 St       529
# ...         ...        ...        ...                           ...       ...
# 72514   2021-07  40.703276 -73.931835            Forrest WH station         1
# 72515   2021-07  40.847410 -73.911359       Townsend Ave & E 175 St         1
# 72516   2021-07  40.874440 -73.891860  Bedford Park Blvd & Paul Ave         1
# 72517   2021-07  40.789622 -73.977570        W 87 St & West End Ave         1
# 72518   2021-07  40.696102 -73.967510     Washington Ave & Park Ave         1
#
# [72519 rows x 5 columns]

# %%
uniqueEndLatLngdf.to_csv('endStationPopularitydf.csv')

# %%
uniqueStartLatLngdf.to_csv('startStationPopularitydf.csv')

# %%
mergeStartLatLngdf = uniqueStartLatLngdf.rename(columns={'start_lat':'lat', 'start_lng':'lng', 'start_station_name':'station_name'})
mergeEndLatLngdf = uniqueEndLatLngdf.rename(columns={'end_lat':'lat', 'end_lng':'lng', 'end_station_name':'station_name'})

# %%
mergedf = mergeStartLatLngdf.merge(mergeEndLatLngdf, on=['monthYear', 'lat', 'lng', 'station_name'])
mergedf
# Out:
#       monthYear        lat        lng                station_name  startCount  \
# 0       2013-06  40.742354 -73.989151          Broadway & W 24 St        2574
# 1       2013-06  40.735243 -73.987586         E 15 St & Irving Pl        1328
# 2       2013-06  40.705693 -74.016777       Little West St & 1 Pl         563
# 3       2013-06  40.734546 -73.990741          Broadway & E 14 St        3119
# 4       2013-06  40.726218 -73.983799           E 7 St & Avenue A        1460
# ...         ...        ...        ...                         ...         ...
# 68829   2021-06  40.860479 -73.905717     Aqueduct Ave & North St           1
# 68830   2021-06  40.674340 -74.001947      Clinton St & Centre St           1
# 68831   2021-06  40.827134 -73.922736  Grand Concourse & E 161 St          45
# 68832   2021-06  40.763505 -73.971092       E 59 St & Madison Ave         105
# 68833   2021-06  40.763505 -73.971092       E 59 St & Madison Ave           1
#
#        endCount
# ...

# %%
mergedf['totalCount'] = mergedf['startCount'] + mergedf['endCount']
mergedf.drop(columns=['startCount', 'endCount'], inplace=True)
mergedf
# Out:
#       monthYear        lat        lng                station_name  totalCount
# 0       2013-06  40.742354 -73.989151          Broadway & W 24 St        5390
# 1       2013-06  40.735243 -73.987586         E 15 St & Irving Pl        2633
# 2       2013-06  40.705693 -74.016777       Little West St & 1 Pl        1226
# 3       2013-06  40.734546 -73.990741          Broadway & E 14 St        6161
# 4       2013-06  40.726218 -73.983799           E 7 St & Avenue A        3021
# ...         ...        ...        ...                         ...         ...
# 68829   2021-06  40.860479 -73.905717     Aqueduct Ave & North St           2
# 68830   2021-06  40.674340 -74.001947      Clinton St & Centre St           2
# 68831   2021-06  40.827134 -73.922736  Grand Concourse & E 161 St          94
# 68832   2021-06  40.763505 -73.971092       E 59 St & Madison Ave         211
# 68833   2021-06  40.763505 -73.971092       E 59 St & Madison Ave           2
#
# [68834 rows x 5 columns]

# %%
mergedf.to_csv('allStationPopularity.csv')

# %%
# Main dfs: alldf_JUST01_2021, all2021_NO_01df

# %%
alldf_JUST01_2021
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1015       2013-12-01 00:00:03       2013-12-01 00:16:58
# 1                 962       2013-12-01 00:00:07       2013-12-01 00:16:09
# 2                 768       2013-12-01 00:00:15       2013-12-01 00:13:03
# 3                 218       2013-12-01 00:00:49       2013-12-01 00:04:27
# 4                 550       2013-12-01 00:01:28       2013-12-01 00:10:38
# ...               ...                       ...                       ...
# 1095341           569  2021-01-31 23:54:00.3610  2021-02-01 00:03:29.8190
# 1095342          1439  2021-01-31 23:55:50.4170  2021-02-01 00:19:49.8980
# 1095343          2619  2021-01-31 23:56:14.9540  2021-02-01 00:39:54.3500
# 1095344            83  2021-01-31 23:59:19.8260  2021-02-01 00:00:43.5840
# 1095345          1313  2021-01-31 23:59:40.4440  2021-02-01 00:21:33.8470
#
#          start station id         start station name  start station latitude  \
# ...

# %%
alldf_JUST01_2021['starttime'] = pd.to_datetime(alldf_JUST01_2021['starttime'])

# %%
alldf_JUST01_2021['stoptime'] = pd.to_datetime(alldf_JUST01_2021['stoptime'])

# %%
alldf_JUST01_2021.to_csv('allOldFormat.csv')

# %%
all2021_NO_01df
# Out:
#                  ride_id rideable_type           started_at  \
# 0       6457BC38526A4187   docked_bike  2021-06-21 10:19:04
# 1       508AC0C37B2BE1A8   docked_bike  2021-06-05 10:12:18
# 2       A1AD52779E13308C   docked_bike  2021-06-04 15:42:35
# 3       DA8AA7083ACCA940   docked_bike  2021-06-03 18:07:42
# 4       BF8DB08AEF78C8D1   docked_bike  2021-06-05 15:39:56
# ...                  ...           ...                  ...
# 649978  84DA58E73B2DF079   docked_bike  2021-02-12 16:01:17
# 649979  3A14299B4F7FA1CF   docked_bike  2021-02-17 18:03:24
# 649980  7B86EE3DC7E026BC   docked_bike  2021-02-28 18:58:31
# 649981  D665B8623FC01285   docked_bike  2021-02-25 09:00:41
# 649982  08A07BB378B0FE2F   docked_bike  2021-02-08 13:31:57
#
#                    ended_at                      start_station_name  \
# 0       2021-06-21 10:26:28                          Lafayette Park
# 1       2021-06-05 10:27:10  Mama Johnson Field - 4 St & Jackson St
# ...

# %%
all2021_NO_01df['started_at'] = pd.to_datetime(all2021_NO_01df['started_at'])

# %%
all2021_NO_01df['ended_at'] = pd.to_datetime(all2021_NO_01df['ended_at'])

# %%
all2021_NO_01df.to_csv('allNewFormat.csv')

# %%
# PHENOMENA DFs
# Main dfs: alldf_JUST01_2021, all2021_NO_01df
# start df2013_06 
# start of JCs: dfJC2015_09

# %%
springdf = pd.concat([df2014_03, df2014_04, df2014_05, df2015_03, df2015_04, df2015_05, df2016_03, df2016_04, df2016_05, 
                    df2017_03, df2017_04, df2017_05, df2018_03, df2018_04, df2018_05, df2019_03, df2019_04, df2019_05, df2020_03, df2020_04, df2020_05, 
                     dfJC2016_03, dfJC2016_04, dfJC2016_05, dfJC2017_03, dfJC2017_04, dfJC2017_05, dfJC2018_03, dfJC2018_04, dfJC2018_05, dfJC2019_03, 
                     dfJC2019_04, dfJC2019_05, dfJC2020_03, dfJC2020_04, dfJC2020_05])

# %%
summerdf = pd.concat([df2013_06, df2013_07, df2013_08, df2014_06, df2014_07, df2014_08, df2015_06, df2015_07, df2015_08, df2016_06, df2016_07, df2016_08, 
                    df2017_06, df2017_07, df2017_08, df2018_06, df2018_07, df2018_08, df2019_06, df2019_07, df2019_08, df2020_06, df2020_07, df2020_08
                    dfJC2016_06, dfJC2016_07, dfJC2016_08, dfJC2017_06, dfJC2017_07, dfJC2017_08, dfJC2018_06, dfJC2018_07, dfJC2018_08, dfJC2019_06, 
                     dfJC2019_07, dfJC2019_08, dfJC2020_06, dfJC2020_07, dfJC2020_08])

# %%
falldf = pd.concat([df2013_09, df2013_10, df2013_11, df2014_09, df2014_10, df2014_11, df2015_09, df2015_10, df2015_11, df2016_09, df2016_10, df2016_11, 
                    df2017_09, df2017_10, df2017_11, df2018_09, df2018_10, df2018_11, df2019_09, df2019_10, df2019_11, df2020_09, df2020_10, df2020_11,
                  dfJC2015_09, dfJC2015_10, dfJC2015_11, dfJC2016_09, dfJC2016_10, dfJC2016_11, dfJC2017_09, dfJC2017_10, dfJC2017_11, dfJC2018_09, 
                   dfJC2018_10, dfJC2018_11, dfJC2019_09, dfJC2019_10, dfJC2019_11, dfJC2020_09, dfJC2020_10, dfJC2020_11])

# %%
winterdf = pd.concat([df2013_12, df2014_12, df2014_01, df2014_02, df2015_12, df2015_01, df2015_02, df2016_12, df2016_01, df2016_02, 
                    df2017_12, df2017_01, df2017_02, df2018_12, df2018_01, df2018_02, df2019_12, df2019_01, df2019_02, df2020_12, df2020_01, df2020_02, 
                    df2021_01, dfJC2015_12, dfJC2016_12, dfJC2016_01, dfJC2016_02, dfJC2017_12, dfJC2017_01, dfJC2017_02, dfJC2018_12, dfJC2018_01, 
                    dfJC2018_02, dfJC2019_12, dfJC2019_01, dfJC2019_02, dfJC2020_12, dfJC2020_01, dfJC2020_02, dfJC2021_01])
